# %% [markdown]
# <a href="https://colab.research.google.com/github/derek-shing/Facebook_Shopify_marketing/blob/master/testing_FacebookAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
r = requests.get(url)

# %%
# Out:
# b'[{"id":"13429079949","type":"PushEvent","actor":{"id":58334128,"login":"otiny","display_login":"otiny","gravatar_id":"","url":"https://api.github.com/users/otiny","avatar_url":"https://avatars.githubusercontent.com/u/58334128?"},"repo":{"id":224857031,"name":"otiny/up","url":"https://api.github.com/repos/otiny/up"},"payload":{"push_id":5645097339,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"295e9088fc67e18f6996962fad35f9ba107c875e","before":"129d0177af092fe4850892c1407b84b94a107e03","commits":[{"sha":"295e9088fc67e18f6996962fad35f9ba107c875e","author":{"email":"58334128+otiny@users.noreply.github.com","name":"otiny"},"message":"update","distinct":true,"url":"https://api.github.com/repos/otiny/up/commits/295e9088fc67e18f6996962fad35f9ba107c875e"}]},"public":true,"created_at":"2020-09-07T00:37:39Z"},{"id":"13429079952","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/
# ...

# %% [markdown]
# **Facebook API call**
#
# Make a POST Request
# To send new events, make a POST request to this API's /events edge from this path: https://graph.facebook.com/{API_VERSION}/{PIXEL_ID}/events?access_token={TOKEN}.

# %%
pip install facebook-business
# Out:
# ...
#      |████████████████████████████████| 1.0MB 2.8MB/s
# ...
#      |████████████████████████████████| 10.1MB 11.8MB/s
# ...
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746865 sha256=8a1d6aa8270936bbb8c41f30a484f3d52e2bb31e55c53c5a9e6a6d2e82f448ca
#   Stored in directory: /root/.cache/pip/wheels/33/4e/a6/be297e6b83567e537bed9df4a93f8590ec01c1acfbcd405348
# ...
#   Created wheel for curlify: filename=curlify-2.2.1-cp36-none-any.whl size=2662 sha256=beb1f1fd02c7f8d6a1549447298c9af34b13534b4ab4a45c1da849ab77fc277c
#   Stored in directory: /root/.cache/pip/wheels/b7/5e/e5/6f90a2b21faf7b71748fcba58920ad77850c25b8f70927d418
# Successfully built pycountry curlify
# ...

# %%
import time

from facebook_business.adobjects.serverside.event import Event
from facebook_business.adobjects.serverside.event_request import EventRequest
from facebook_business.adobjects.serverside.user_data import UserData
from facebook_business.adobjects.serverside.custom_data import CustomData
from facebook_business.api import FacebookAdsApi

access_token =
pixel_id =

FacebookAdsApi.init(access_token=access_token)

user_data = UserData(
    email='joe@eg.com',
    fbc='fb.1.1554763741205.AbCdEfGhIjKlMnOpQrStUvWxYz1234567890',
    fbp='fb.1.1558571054389.1098115397'
)

custom_data = CustomData(
    currency='usd',
    value=123.45
)

event = Event(
    event_name='Purchase',
    event_time=int(time.time()),
    user_data=user_data,
    custom_data=custom_data,
)

events = [event]

event_request = EventRequest(
    events=events,
    pixel_id=pixel_id)

event_response = event_request.execute()
print(event_response)
# Out:
# {'events_received': 1, 'fbtrace_id': 'AXhW4yhWP8NmYXKs-sHDLJT', 'messages': []}
